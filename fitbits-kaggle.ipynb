# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.1 Loading the dataframe

# %%
df = pd.read_csv("/kaggle/input/calories-burned-during-exercise-and-activities/exercise_dataset.csv")
df.iloc[[37,38]]

# %% [markdown]
# # 1.2 Calculating calories burned according to weight
#
#  calories burned using the **"Calories per kg"** column.
#
# > weight * df.iloc[exercise_index]["Calories per kg"]
#
# * exercise_index : Index of the exercise in the dataframe

# %%
#  weight is 130 lb,
weight = 130

# running moderately for 1 hour
# This exercise is at index 36 in df

print("Calories burned:", weight*df.iloc[36]["Calories per kg"] , "kcal")

# %% [markdown]
# # 1.3 Visualizing the calories burned by each exercise

# %%
plt.scatter(df.index, df["130 lb"])
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("Scatter plot for calories burned vs exercise index (130 lb)")
plt.show()

# %% [markdown]
# # 1.4 Getting information about the most intensive exercises/activities
#
# Here you can see the most intensive exercises sorted on the basis of the calories burned per hour.

# %%
# Here the weight is 130 lb, you change the weight
weight = 130

# dancing moderately for 1 hour
# This exercise is at index 35 in df

print("Calories burned:", weight*df.iloc[35]["Calories per kg"] , "kcal")

# %%
#histogram


df["Calories per kg"].plot(kind = 'hist')

# %%
#correlation
df.corr()

# %%
#print info
print(df.info())

# %%
#print and remove any null values

import pandas as pd

df = pd.read_csv('data.csv')

df.dropna(inplace = True)

print(df.to_string())
