# %% [markdown]
# <a href="https://colab.research.google.com/github/deartc/FitBitLit/blob/main/ExerciseDataRead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print to string

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

df['Date'] = pd.to_datetime(df['Date'])

print(df.to_string())









# print max rows
import pandas as pd

pd.options.display.max_rows = 200

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

print(df) 



# print 
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

print(df.head())




#print info
print(df.info()) 



#print dataframe no empty cells
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

new_df = df.dropna()

print(new_df.to_string())





#print and remove any null values

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

df.dropna(inplace = True)

print(df.to_string())




#Replace empty cells with a value

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

df.fillna(130, inplace = True)



#replace with mean

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)




#replace with median


import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

x = df["Calories"].median()

df["Calories"].fillna(x, inplace = True)



#replace with mode

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/datasets.csv')

x = df["Calories"].mode()[0]

df["Calories"].fillna(x, inplace = True)




#replace

df.dropna(subset=['Date'], inplace = True)





#histogram


df["Duration"].plot(kind = 'hist')




#replace wrong values with new


for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.loc[x, "Duration"] = 120 





#delete data
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.drop(x, inplace = True)



#remove duplicates
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.drop(x, inplace = True)






#correlation
df.corr()


#visualize  scatter
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
