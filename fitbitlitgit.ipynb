# %% [markdown]
# <a href="https://colab.research.google.com/github/deartc/FitBitLit/blob/main/fitbitlitgit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Please make a copy of this notebook before using it. Go to Files > Save a Copy in Drive**

# %% [markdown]
# ## **Importing necessary libraries**

# %%
#Data Manipulation
import pandas as pd

#Plotting
import seaborn as sns
import matplotlib.pyplot as plt

#Importing Dataset
from sklearn import datasets


# import datetime and format date for current date and future date to meet criteria
import datetime
# import re for regular expressions
import re

# %%
# extract emails from String By Regular Expression

s = """ Group fitness class information email teresalynnhawkins@gmail.com
         and the website ExerciseTogether@google.com"""

# \S matches any non-whitespace,@ for as in the Email
# + for Repeats a character one or more times
Contact = re.findall('\S+@\S+', s)
print(Contact)
# code for  datetime and format date for current date and future date to meet criteria
Current_Date_Formatted = datetime.datetime.today().strftime('%d-%b-%Y')
print('Fitness Start Date: ' + str(Current_Date_Formatted))

# datetime(year, month, day, hour, minute, second)
a = datetime.datetime(2022, 4, 22, 18, 25, 30)
b = datetime.datetime(2022, 2, 3, 8, 21, 10)

# returns the Time difference in days
c = a - b
print('Difference between Fitness Start Date and KY Marathon: ', c)


#this is the dictionary of certain exercises and calories burned

dict1 = {'walk': 100, 'hike': 110, 'stroll': 80,
         'pilates': 90, 'stretching': 100, 'yoga': 90}
dict2 = {'football': 200, 'basketball': 130, 'soccer': 200, 'tennis': 100, 'squash': 140, 'running': 160,
         'badminton': 100, 'hike': 110}
result = {}

print("lower calorie exercises", dict1)
print("higher calorie exercises", dict2)

# intersect dictionaries
# Create a new dictionary which is the intersection of two dictionaries.
# Both key & value must match

# calorie count intersection
for key in dict1:
    if key in dict2 and dict1[key] == dict2[key]:
        result[key] = dict1[key]

print("Exercises that  are intermediate calorie burners"
      " ", result)





      

#  print This is the students exercising together and their data

print("This is the students exercising together and their data")
# Out:
# ['teresalynnhawkins@gmail.com', 'ExerciseTogether@google.com']
# Fitness Start Date: 10-Mar-2022
# Difference between Fitness Start Date and KY Marathon:  78 days, 10:04:20
# lower calorie exercises {'walk': 100, 'hike': 110, 'stroll': 80, 'pilates': 90, 'stretching': 100, 'yoga': 90}
# higher calorie exercises {'football': 200, 'basketball': 130, 'soccer': 200, 'tennis': 100, 'squash': 140, 'running': 160, 'badminton': 100, 'hike': 110}
# Exercises that  are intermediate calorie burners  {'hike': 110}
# This is the students exercising together and their data

# %% [markdown]
# PROCESSING DATA

# %%
# print all raw unclean data 


pd.options.display.max_rows = 400

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

print(df) 



# print 
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

print(df.head())




#print info
print(df.info())
# Out:
#      Duration        Date  Pulse  Steps  Calories Exerciser
# 0          60   12/1/2021    115  10460     509.1      Madi
# 1          60   12/2/2021    117  14846     679.0      Madi
# 2          60   12/3/2021    103  14135     340.0      Madi
# 3          45   12/4/2021    109  10176     382.4      Madi
# 4          45   12/5/2021    117   9948     416.0      Madi
# 5          60   12/6/2021    102   9427     300.0      Madi
# 6          60   12/7/2021    110   9925     374.0      Madi
# 7         450   12/8/2021    104   9934     255.3      Madi
# 8          30   12/9/2021    109   8933     195.1      Madi
# 9          60  12/10/2021     98   9865     269.0      Madi
# 10         60  12/11/2021    103   9947     329.3      Madi
# 11         60  12/12/2021    100   8720     250.7      Madi
# 12         60  12/12/2021    100   7825     250.7      Madi
# 13         60  12/13/2021    106  10128     345.3      Madi
# 14         60  12/14/2021    104  10332     379.3      Madi
# ...

# %%
#Read the data and display the first five elements

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')
df.head()
# Out:
#    Duration       Date  Pulse  Steps  Calories Exerciser
# 0        60  12/1/2021    115  10460     509.1      Madi
# 1        60  12/2/2021    117  14846     679.0      Madi
# 2        60  12/3/2021    103  14135     340.0      Madi
# 3        45  12/4/2021    109  10176     382.4      Madi
# 4        45  12/5/2021    117   9948     416.0      Madi

# %%
#print info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Duration   120 non-null    int64
#  1   Date       120 non-null    object
#  2   Pulse      120 non-null    int64
#  3   Steps      120 non-null    int64
#  4   Calories   113 non-null    float64
#  5   Exerciser  120 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.8+ KB
# None

# %%
#print datasetframe no empty cells and print cleaned data to meet project show clean data


df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#      Duration        Date  Pulse  Steps  Calories Exerciser
# 0          60   12/1/2021    115  10460     509.1      Madi
# 1          60   12/2/2021    117  14846     679.0      Madi
# 2          60   12/3/2021    103  14135     340.0      Madi
# 3          45   12/4/2021    109  10176     382.4      Madi
# 4          45   12/5/2021    117   9948     416.0      Madi
# 5          60   12/6/2021    102   9427     300.0      Madi
# 6          60   12/7/2021    110   9925     374.0      Madi
# 7         450   12/8/2021    104   9934     255.3      Madi
# 8          30   12/9/2021    109   8933     195.1      Madi
# 9          60  12/10/2021     98   9865     269.0      Madi
# 10         60  12/11/2021    103   9947     329.3      Madi
# 11         60  12/12/2021    100   8720     250.7      Madi
# 12         60  12/12/2021    100   7825     250.7      Madi
# 13         60  12/13/2021    106  10128     345.3      Madi
# 14         60  12/14/2021    104  10332     379.3      Madi
# ...

# %%
#print and remove any null values and print data to meet project show clean data


df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

df.dropna(inplace = True)

print(df.to_string())
# Out:
#      Duration        Date  Pulse  Steps  Calories Exerciser
# 0          60   12/1/2021    115  10460     509.1      Madi
# 1          60   12/2/2021    117  14846     679.0      Madi
# 2          60   12/3/2021    103  14135     340.0      Madi
# 3          45   12/4/2021    109  10176     382.4      Madi
# 4          45   12/5/2021    117   9948     416.0      Madi
# 5          60   12/6/2021    102   9427     300.0      Madi
# 6          60   12/7/2021    110   9925     374.0      Madi
# 7         450   12/8/2021    104   9934     255.3      Madi
# 8          30   12/9/2021    109   8933     195.1      Madi
# 9          60  12/10/2021     98   9865     269.0      Madi
# 10         60  12/11/2021    103   9947     329.3      Madi
# 11         60  12/12/2021    100   8720     250.7      Madi
# 12         60  12/12/2021    100   7825     250.7      Madi
# 13         60  12/13/2021    106  10128     345.3      Madi
# 14         60  12/14/2021    104  10332     379.3      Madi
# ...

# %%
#print to string the calories 



df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

df['Calories'] = pd.to_numeric(df['Calories'])

print(df.to_string())
# Out:
#      Duration        Date  Pulse  Steps  Calories Exerciser
# 0          60   12/1/2021    115  10460     509.1      Madi
# 1          60   12/2/2021    117  14846     679.0      Madi
# 2          60   12/3/2021    103  14135     340.0      Madi
# 3          45   12/4/2021    109  10176     382.4      Madi
# 4          45   12/5/2021    117   9948     416.0      Madi
# 5          60   12/6/2021    102   9427     300.0      Madi
# 6          60   12/7/2021    110   9925     374.0      Madi
# 7         450   12/8/2021    104   9934     255.3      Madi
# 8          30   12/9/2021    109   8933     195.1      Madi
# 9          60  12/10/2021     98   9865     269.0      Madi
# 10         60  12/11/2021    103   9947     329.3      Madi
# 11         60  12/12/2021    100   8720     250.7      Madi
# 12         60  12/12/2021    100   7825     250.7      Madi
# 13         60  12/13/2021    106  10128     345.3      Madi
# 14         60  12/14/2021    104  10332     379.3      Madi
# ...

# %%
#visualize  scatter to show distribution of steps



df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

df.plot(kind = 'scatter', x = 'Exerciser', y = 'Calories')

plt.show()

from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
#visualize  scatter


df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

df.plot(kind = 'scatter', x = 'Exerciser', y = 'Steps')

plt.show()

# %%
#histogram

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

df.plot(kind = 'hist', x = 'Exerciser', y = 'Calories')

plt.show


df['Calories'].plot(kind = 'hist')



from google.colab import data_table
data_table.enable_dataframe_formatter()



#correlation
df.corr()
# Out:
#           Duration     Pulse     Steps  Calories
# Duration  1.000000 -0.007168  0.034506 -0.055230
# Pulse    -0.007168  1.000000  0.189559  0.000622
# Steps     0.034506  0.189559  1.000000  0.089889
# Calories -0.055230  0.000622  0.089889  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt




#histogr

df = pd.read_csv('https://raw.githubusercontent.com/deartc/FitBitLit/main/increaseddata.csv')

df.plot(kind = 'hist', x = 'Calories', y = 'Steps')

plt.show()


df['Calories'].plot(kind = 'hist')



from google.colab import data_table
data_table.enable_dataframe_formatter()



#correlation
df.corr()
# Out:
#           Duration     Pulse     Steps  Calories
# Duration  1.000000 -0.007168  0.034506 -0.055230
# Pulse    -0.007168  1.000000  0.189559  0.000622
# Steps     0.034506  0.189559  1.000000  0.089889
# Calories -0.055230  0.000622  0.089889  1.000000

# %%
#The last 5 elements of the dataset
df.tail()
# Out:
#      Duration        Date  Pulse  Steps  Calories Exerciser
# 115        60  12/25/2021    102   9126     834.5      Guil
# 116        60  12/26/2021    100  11129     850.0      Guil
# 117        60  12/27/2021     92  10118     841.0      Guil
# 118        60  12/28/2021    103  12132       NaN      Guil
# 119        60  12/29/2021    100  13132    1080.0      Guil

# %%
#Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Duration   120 non-null    int64
#  1   Date       120 non-null    object
#  2   Pulse      120 non-null    int64
#  3   Steps      120 non-null    int64
#  4   Calories   113 non-null    float64
#  5   Exerciser  120 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.8+ KB

# %%
#Statistical Description of the Dataset
df.describe()
# Out:
#         Duration       Pulse         Steps     Calories
# count  120.00000  120.000000    120.000000   113.000000
# mean    58.87500  103.975000   9562.050000   671.826549
# std     36.85346    7.742128   2710.826126   819.573112
# min     30.00000   90.000000   3733.000000   195.100000
# 25%     45.00000  100.000000   8044.750000   300.000000
# 50%     60.00000  103.000000   9131.000000   509.100000
# 75%     60.00000  108.000000  10767.000000   874.000000
# max    450.00000  130.000000  19147.000000  8300.000000

# %%
#Number of rows and columns in the dataset
df.shape
# Out:
# (120, 6)

# %%
#Number of null values per column
df.isnull().sum()
# Out:
# Duration     0
# Date         0
# Pulse        0
# Steps        0
# Calories     7
# Exerciser    0
# dtype: int64

# %%
#Columns of the dataset
df.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Steps', 'Calories', 'Exerciser'], dtype='object')

# %% [markdown]
# ## **Data Visualization as Heat Map**

# %%
sns.heatmap(df.corr())
