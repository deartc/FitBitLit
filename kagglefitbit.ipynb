# %% [markdown]
# <a href="https://www.kaggle.com/terrybishop/kagglefitbit?scriptVersionId=88827065" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
#  # 1.1 Exercises and Calories Burnt

# %%
df = pd.read_csv("/kaggle/input/calories-burned-during-exercise-and-activities/exercise_dataset.csv")
df.head(40)
# Out:
#         Activity, Exercise or Sport (1 hour)  130 lb  155 lb  180 lb  205 lb  \
# 0                Cycling, mountain bike, bmx     502     598     695     791
# 1        Cycling, <10 mph, leisure bicycling     236     281     327     372
# 2                   Cycling, >20 mph, racing     944    1126    1308    1489
# 3                Cycling, 10-11.9 mph, light     354     422     490     558
# 4             Cycling, 12-13.9 mph, moderate     472     563     654     745
# 5             Cycling, 14-15.9 mph, vigorous     590     704     817     931
# 6      Cycling, 16-19 mph, very fast, racing     708     844     981    1117
# 7                                 Unicycling     295     352     409     465
# 8             Stationary cycling, very light     177     211     245     279
# 9                  Stationary cycling, light     325     387     449     512
# 10              Stationary cycling, moderate     413     493     572     651
# ...

# %% [markdown]
# # Exercisers specific exercises used in below calculations of calories

# %%
df = pd.read_csv("/kaggle/input/calories-burned-during-exercise-and-activities/exercise_dataset.csv")
df.iloc[[27,37,38,39]]
# Out:
#    Activity, Exercise or Sport (1 hour)  130 lb  155 lb  180 lb  205 lb  \
# 27              Aerobics, step aerobics     502     598     695     791
# 37      Running, 5 mph (12 minute mile)     472     563     654     745
# 38  Running, 5.2 mph (11.5 minute mile)     531     633     735     838
# 39         Running, 6 mph (10 min mile)     590     704     817     931
#
#     Calories per kg
# 27         1.750730
# 37         1.647825
# 38         1.852957
# 39         2.059443

# %% [markdown]
# # Maddie's weight is 130 lb,
#
# # running 12 mph for 1 hour
# # This exercise is at index 37 in df

# %%
# Maddie's is 130 lb, 
weight = 130

# running 12 mph for 1 hour
# This exercise is at index 37 in df

print("Calories burned:", weight*df.iloc[37]["Calories per kg"] , "kcal")
# Out:
# Calories burned: 214.21728453731322 kcal

# %% [markdown]
# # Evan's  weight is 180 lb,
#
#
# # running 11.5 mph for 1 hour
# # This exercise is at index 38 in df

# %%
# Evan is 155 lb
weight = 155

# running 11.5 mph for 1 hour
# This exercise is at index 38 in df

print("Calories burned:", weight*df.iloc[38]["Calories per kg"] , "kcal")
# Out:
# Calories burned: 287.20836137313376 kcal

# %% [markdown]
# # Gabby's weight is 180 lb,
#
#  # This exercise is at index 39 in df

# %%
# Gabbys's weigh is 180 lb, 
weight = 180

# running 10 mph for 1 hour
# This exercise is at index 39 in df

print("Calories burned:", weight*df.iloc[39]["Calories per kg"] , "kcal")
# Out:
# Calories burned: 370.69975450746364 kcal

# %% [markdown]
# # Guil's weigh is 205 lb,
#
# ​
# # stepping 1 hour
# # This exercise is at index 27 in df
# ​

# %%
# Guil's weigh is 205 lb, 
weight = 205

# stepping for 1 hour
# This exercise is at index 27 in df

print("Calories burned:", weight*df.iloc[27]["Calories per kg"] , "kcal")
# Out:
# Calories burned: 358.89959247761294 kcal

# %% [markdown]
# # 1.3 Visualizing the calories burned by each exercise

# %%
plt.scatter(df.index, df["130 lb"])
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("Scatter plot for calories burned vs exercise index (130 lb)")
plt.show()

# %%
plt.scatter(df.index, df["Calories per kg"])
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("Scatter plot for calories burned vs exercise index (130 lb)")
plt.show()

# %%
df["Calories per kg"].plot(kind = 'hist')
plt.xlabel("Index (exercise)")
plt.ylabel("Calories burned")
plt.title("calories burned vs exercise index")
plt.show()

# %%
df.corr()
# Out:
#                    130 lb    155 lb    180 lb    205 lb  Calories per kg
# 130 lb           1.000000  0.999999  0.999999  0.999999         1.000000
# 155 lb           0.999999  1.000000  0.999999  0.999999         0.999999
# 180 lb           0.999999  0.999999  1.000000  0.999999         1.000000
# 205 lb           0.999999  0.999999  0.999999  1.000000         1.000000
# Calories per kg  1.000000  0.999999  1.000000  1.000000         1.000000

# %%
#print info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 6 columns):
# Activity, Exercise or Sport (1 hour)    248 non-null object
# 130 lb                                  248 non-null int64
# 155 lb                                  248 non-null int64
# 180 lb                                  248 non-null int64
# 205 lb                                  248 non-null int64
# Calories per kg                         248 non-null float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 11.8+ KB
# None
